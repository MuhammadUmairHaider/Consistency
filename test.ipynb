# %%
from models.distilbert import DistilBertForSequenceClassification
from transformers import AutoModelForSequenceClassification, AutoTokenizer
from datasets import load_dataset
from utilities import compute_accuracy
import torch
import os

directory_path = "distilbert-base-uncased-finetuned-emotion"

if not os.path.exists(directory_path):
    os.makedirs(directory_path)

weights_path = os.path.join(directory_path, "weights.pth")

model = AutoModelForSequenceClassification.from_pretrained("lvwerra/distilbert-imdb", force_download=True)

model.config.m_layer = 5

#save weights
torch.save(model.state_dict(), weights_path)

tokenizer = AutoTokenizer.from_pretrained("esuriddick/distilbert-base-uncased-finetuned-emotion")

model = DistilBertForSequenceClassification(model.config)
#load weights
model.load_state_dict(torch.load(weights_path))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 15
#      11     os.makedirs(directory_path)
#      13 weights_path = os.path.join(directory_path, "weights.pth")
# ---> 15 model = AutoModelForSequenceClassification.from_pretrained("lvwerra/distilbert-imdb", force_download=True)
#      17 model.config.m_layer = 5
#      19 #save weights
#
# File ~/anaconda3/envs/memit/lib/python3.9/site-packages/transformers/models/auto/auto_factory.py:523, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     520 if kwargs.get("quantization_config", None) is not None:
#     521     _ = kwargs.pop("quantization_config")
# --> 523 config, kwargs = AutoConfig.from_pretrained(
#     524     pretrained_model_name_or_path,
#     525     return_unused_kwargs=True,
#     526     trust_remote_code=trust_remote_code,
# ...

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSequenceClassification
model = AutoModelForSequenceClassification.from_pretrained("sharmax-vikas/bert-base-banking77-pt2")
tokenizer = AutoTokenizer.from_pretrained("sharmax-vikas/bert-base-banking77-pt2")

# %%
for n,m in model.named_modules():
    print(n)
# Out:
# bert
# bert.embeddings
# bert.embeddings.word_embeddings
# bert.embeddings.position_embeddings
# bert.embeddings.token_type_embeddings
# bert.embeddings.LayerNorm
# bert.embeddings.dropout
# bert.encoder
# bert.encoder.layer
# bert.encoder.layer.0
# bert.encoder.layer.0.attention
# bert.encoder.layer.0.attention.self
# bert.encoder.layer.0.attention.self.query
# bert.encoder.layer.0.attention.self.key
# bert.encoder.layer.0.attention.self.value
# bert.encoder.layer.0.attention.self.dropout
# bert.encoder.layer.0.attention.output
# bert.encoder.layer.0.attention.output.dense
# bert.encoder.layer.0.attention.output.LayerNorm
# bert.encoder.layer.0.attention.output.dropout
# bert.encoder.layer.0.intermediate
# bert.encoder.layer.0.intermediate.dense
# bert.encoder.layer.0.intermediate.intermediate_act_fn
# bert.encoder.layer.0.output
# bert.encoder.layer.0.output.dense
# bert.encoder.layer.0.output.LayerNorm
# bert.encoder.layer.0.output.dropout
# bert.encoder.layer.1
# ...

# %%
from models.bert import BertForSequenceClassification
import os
import torch

model = BertForSequenceClassification(model.config)

directory_path = "bert-base-banking77-pt2"

if not os.path.exists(directory_path):
    os.makedirs(directory_path)

weights_path = os.path.join(directory_path, "weights.pth")

model = AutoModelForSequenceClassification.from_pretrained("sharmax-vikas/bert-base-banking77-pt2")

model.config.m_layer = 5

#save weights
torch.save(model.state_dict(), weights_path)

model = BertForSequenceClassification(model.config)
#load weights
model.load_state_dict(torch.load(weights_path))
# Out:
# <All keys matched successfully>

# %%
dataset_all = load_dataset("dair-ai/emotion")
# Select the train split
dataset_all = dataset_all['train']
text_tag = 'text'


for j in range(0,7):
    dataset = dataset_all.filter(lambda x: x['label'] in [j])
    dataset_complement = dataset_all.filter(lambda x: x['label'] not in [j])
    
    if(j==6):
        dataset = dataset_all
        
    acc = compute_accuracy(dataset, model, tokenizer, text_tag)
    print("Class ",j, "base accuracy: ", acc)
# Out:
# ...
# 100%|██████████| 4666/4666 [00:17<00:00, 268.01it/s]
# Class  0 base accuracy:  (0.9961, 0.9946)
# 100%|██████████| 5362/5362 [00:20<00:00, 262.26it/s]
# Class  1 base accuracy:  (0.9875, 0.9868)
# 100%|██████████| 1304/1304 [00:05<00:00, 253.51it/s]
# Class  2 base accuracy:  (0.9893, 0.9512)
#  18%|█▊        | 394/2159 [00:01<00:06, 260.31it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 14
#      11 if(j==6):
#      12     dataset = dataset_all
# ---> 14 acc = compute_accuracy(dataset, model, tokenizer, text_tag)
#      15 print("Class ",j, "base accuracy: ", acc)
#
# File /mounts/u-amo-d1/grad/mha361/work/probless/Sentiment/utilities.py:21, in compute_accuracy(dataset, model, tokenizer, text_tag)
#      19 outputs = model(**inputs)
#      20 predictions = torch.nn.functional.softmax(outputs[0], dim=-1)
# ...

# %%
mask = torch.ones(model.config.hidden_size).to("cuda")

model.distilbert.transformer.masking_layer = mask
